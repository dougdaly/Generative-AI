# %% [markdown]
# # Step 3: A2A Supply Chain Planner (Coordinator + Specialists)
#
# In Step 1, we used A2A discovery + specialist selection (A2A Olympics).
# In Step 2, we used A2A coordination (PEMDAS AST reducer routing sub-ops to specialists).
#
# ## Overview
# ### Goal: build a Coordinator agent that:
# <ol>
# <li><b>plans</b> (decides what work needs doing)</li>
# <li><b>selects</b> specialists (based on skills + constraints)</li>
# <li><b>executes</b> (iterates search under a compute budget)</li>
# <li><b>validates</b> every step with contracts + scoring</li>
# <li><b>produces</b> an auditable trace a human can agree with</li>
# </ol>
#
# The demo is supply-chain flavored because:<ul>
# <li>Most people understand “raw materials → assembly → shipping → tariffs”</li>
# <li>It’s timely</li>
# <li>There’s a clear objective function (min cost + satisfy constraints)</li>
# <li>The “why” is inspectable: every action has a measurable effect</li>
# </ul>

# %% [markdown]
# ### What We’re Demonstrating
# What “Coordinator Intelligence” Means Here (No Handwaving)
#
# We are not trying to prove the coordinator is “smart” by vibes.
#
# We prove it by showing:
#
# ✅ It produces a plan (search strategy + candidate generation)</br>
# ✅ It makes decisions (tradeoffs + constraint handling)</br>
# ✅ It adapts to budget (more budget ⇒ better solutions, better confidence)</br>
# ✅ It creates a full trace (every hop has inputs/outputs/latency)</br>
# ✅ It never silently cheats (contracts + schemas on the wire)</br>
#
# Success is not “best solution in the world.”</br>
# Success is: a valid solution + a readable decision trail.

# %% [markdown]
# ### Agents and Responsibilities
# #### A2A Agents (Roles)
# <b>Coordinator</b>
# <ul><li>Inputs: scenario + constraints + budget</li>
# <li>Outputs: best plan found + full trace</li>
# <li>Chooses strategy (greedy/beam/random_restart/anneal) based on policy/adaptive settings</li>
# </ul>
# <b>Specialist Agents (skills)</b>
# <ul><li>tariff.calc → compute duties given origin/destination/product class</li>
# <li>route.enumerate → generate feasible next steps from a partial plan</li>
# <li>plan.score → compute total landed cost + penalties</li>
# <li>plan.validate → enforce hard constraints + explain violations</li>
# <li>plan.repair (optional later) → attempt minimal edits to fix invalid plans
# </ul>
# In v1, these can be deterministic Python logic behind A2A endpoints.</br>
# No LLM required.

# %% [markdown]
# ### Message Format (Envelope + Typed Payload)
# <b>Wire Contract + Payload Contract</b> (Same Pattern as PEMDAS)</br></br>
# Each hop sends:</br>
# <b>A2A Envelope</b>
# <ul><li>source, dest, timestamp, trace_id, request_id</li>
# <li>message_type</li>
# <li>payload</li>
# </ul></br>
# <b>Typed Payload</b> - validated by JSON Schema per message_type</br>
# This keeps the whole system honest:
# <ul><li>specialists can be swapped without breaking protocol</li>
# <li>coordinator can debug failures precisely</li>
# <li>logs are structured and replayable</li>
# </ul>

# %% [markdown]
# ### Strategy Control: Selection Method + Strategy
# <b>Strategy Control Vocabulary</b></br>
# We use two terms:<br>
#
# 1) selection_method
# <ul><li>fixed → force a specific strategy (testing)</li>
# <li>policy → rules-based selection (configured)</li>
# <li>adaptive → coordinator changes strategy mid-run (later)</li></ul>
#
# 2) strategy
# <ul><li>greedy → best immediate improvement</li>
# <li>beam → keep top-k candidates per depth</li>
# <li>random_restart → escape local minima with multiple seeds</li>
# <li>anneal → accept worse steps early; tighten later (optional)</li>
# </ul>
#
# <b>What's stored</b>:
# <ul><li>strategy_requested (what user asked for; can be null)</li>
# <li>strategy_selected (what we actually ran)</li>
# <li>selection_reason (why)</li></ul></br>
#
# **Example**
#
# ```json
# {
#   "selection_method": "adaptive",
#   "strategy_requested": None,
#   "strategy_selected": "beam",
#   "selection_reason": "budget=200; need diversity + constraint satisfaction"
# }
# ```

# %% [markdown]
# ### Compute Budget and “Learning Curve”
# <b>Budget Drives Behavior</b></br>
# We expose compute_budget as a first-class parameter.
#
# Interpretation:
# <ul><li>small budgets: shallow search (greedy)</li>
# <li>medium budgets: maintain diversity (beam)</li>
# <li>large budgets: explore/escape minima (random_restart / anneal)</li></ul>
# </br>
# We do NOT hardcode:
# “if budget < 20 use greedy”
#
# Instead we implement a policy module:
# <ul><li>look-up-table now (simple, explainable)</li>
# <li>adaptive switching later (based on progress indicators)</li></ul>
# </br>
# <b>Key artifact for the post</b>:</br>
# Show the same scenario solved with budgets 20 vs 200 vs 2000
# and demonstrate solution quality improving + confidence increasing

# %% [markdown]
# ### Execution Loop
# #### <b>Coordinator Execution Loop (v1)</b></br>
# <b>Inputs</b>:<ul>
# <li>scenario data (suppliers, costs, lead times, tariffs)</li>
# <li>constraints (must-haves)</li>
# <li>objective weights (cost vs speed vs risk)</li>
# <li>compute budget</li></ul>
# </br>
# <b>Algorithm</b>:<ol>
# <li>initialize candidate set (seed plans)</li>
# <li>repeat until budget exhausted:
# <ul><li>expand candidates (route.enumerate)</li>
# <li>score candidates (plan.score)</li>
# <li>validate candidates (plan.validate)</li>
# <li>keep best subset (strategy controls this)</li></ul></li>
# <li>return best valid plan + explanation trace</li>
# </ol></br>
#
# <b>Outputs</b>:<ul>
# <li>best plan found</li>
# <li>total cost breakdown</li>
# <li>validation status</li>
# <li>full trace (calls + latency + deltas per step)</li>
# </ul>

# %% [markdown]
# ### Trace Format
# Trace = Debuggable Coordination
#
# Every iteration stores a trace event like:
#
# ```json
# {
#   "step": 12,
#   "strategy_effective": "beam",
#   "candidate_id": "cand-04",
#   "action": "expand",
#   "call": {
#     "agent": "ROUTE_ENUM",
#     "message_type": "route.enumerate:v1",
#     "request_id": "...",
#     "latency_ms": 18.2
#   },
#   "before": {"partial_plan": "..."},
#   "after": {"new_candidates": 5}
# }
# ```
# </br>
# This is the “aha”:<ul>
# <li>coordination is not a black box</li>
# <li>the coordinator is not “thinking,” it’s operating</li>
# </ul>

# %% [markdown]
# ### Milestones (Incremental Build Plan)
# #### Build Plan (Incremental)
# **Milestone 0 — Contracts**: define schemas for
# <ul><li>scenario input</li>
# <li>plan candidate</li>
# <li>scoring output</li>
# <li>validation result</li>
# <li>coordinator request/response</li></ul>
#
# **Milestone 1 — Specialists**: implement deterministic specialists as A2A services
# <ul><li>validate</li>
# <li>score</li>
# <li>enumerate</li></ul>
#
# **Milestone 2 — Coordinator v1**
# <ul><li>fixed strategy (greedy)</li>
# <li>returns a valid plan + trace</li></ul>
#
# **Milestone 3 — Coordinator v1.1**
# <ul><li>selection_method = fixed | policy</li>
# <li>run same scenario under 20 / 200 / 2000 budget</li>
# </ul>
#
# **Milestone 4 — Adaptive**
# <ul><li>switch strategy mid-run if progress stalls</li>
# <li>store strategy_selected_initial/final</li></ul>
#
# **Milestone 5 — Post assets**
# <ul><li>banner diagram</li>
# <li>trace snippet</li>
# <li>comparison chart: budget vs best score</li>
# </ul>

# %% [markdown]
# ### Risk Management (aka “Reality”)
# **Known Risk: Theory vs Practice**
#
# Even with clean A2A plumbing, failures will happen:
# <ul><li>schema drift (payload mismatch)</li>
# <li>registry discovery issues (wrong agent, wrong endpoint)</li>
# <li>search getting stuck in bad local minima</li>
# <li>trace bloat / unreadable output</li></ul>
# </br>
# We mitigate by:
# <ul><li>strict validation at every hop</li>
# <li>small scenario first (3 suppliers, 2 routes)</li>
# <li>consistent trace format</li>
# <li>locked “fixed strategy” mode for debugging</li></ul>

# %% [markdown]
# ## Execution outline
# ### Milestone 0: Contract Map
# **Contract Map (What each schema is for)**
#
# We split contracts into two layers:
#
# A) General A2A wire contracts (shared across projects)
# <ul><li>a2a_request_v1.json</li>
# <li>a2a_response_v1.json</li>
# </ul>
# These define the envelope (routing + traceability).
#
# B) Project-specific payload contracts (this demo only)
# <ul><li>supply_problem_v1.json</li>
# <li>supply_plan_v1.json</li>
# <li>supply_price_v1.json</li>
# <li>supply_price_breakdown_v1.json</li>
# <li>(optional but recommended) supply_trace_event_v1.json, supply_strategy_config_v1.json</li></ul>
# </br>
# These define the meaningful data that agents compute and pass around.
#
# Envelope = “how messages travel”
# Payload = “what the messages mean”

# %% [markdown]
# #### A2A Wire Contracts (Protocol Layer)
#
# <b><i>a2a_request_v1.json</i></b>
#
# **Purpose**: Standard wrapper for sending a typed message to an agent.
#
# Used by: coordinator → specialists, user → coordinator
#
# Key fields:
# <ul><li>request_id (UUID): unique per request</li>
# <li>trace_id (UUID): shared across the whole run</li>
# <li>timestamp: when the request was created</li>
# <li>source / dest: endpoints (who is calling who)</li>
# <li>message_type: the “payload type”</li>
# <li>payload: object validated by the schema implied by message_type</li></ul>
#
# Mental model: “an addressed envelope containing typed data.”
# </br></br>
# <b><i>a2a_response_v1.json</i></b>
#
# <b>Purpose</b>: Standard wrapper for returning results (or errors).
#
# Used by: specialists → coordinator, coordinator → user</br>
# Key fields:
# <ul><li>request_id: matches the request</li>
# <li>trace_id: same trace</li>
# <li>timestamp: response time</li>
# <li>ok: boolean
# <ul><li>if ok=True: payload exists and is validated by message_type</li>
# <li>if ok=False: error exists (structured)</li></ul>
# </ul>
# Mental model: “receipt + contents + error handling.”

# %% [markdown]
# #### Supply Chain Payload Contracts (Demo Layer)
#
# These define what the supply-chain demo means in data.
#
# <b><i>supply_problem_v1.json</i></b></br></br>
# <b>Purpose</b>: The entire scenario definition and constraints.</br>
# <b>Produced by</b>: user / notebook</br>
# <b>Consumed by</b>: coordinator (and sometimes route.enumerate)</br>
#
# **Typical contents**:<ul>
# <li>suppliers: costs, countries, capacities</li>
# <li>manufacturing options: allowed assembly countries, costs</li>
# <li>shipping options: lanes + time/cost</li>
# <li>tariff policy: duties by origin/destination/category (simplified table)</li>
# <li>constraints:<ul>
# <li>max lead time</li>
# <li>min quality score</li>
# <li>banned countries</li>
# <li>min capacity</li></ul></li>
# <li>objective weights:
# <ul><li>landed_cost weight</li>
# <li>speed weight</li>
# <li>risk weight</li></ul></li>
# </ul>
# Why it exists: Without this contract, everyone “assumes” the scenario. That’s how demos lie.
# </br></br>
#
# <b><i>supply_plan_v1.json</i></b></br></br>
# <b>Purpose</b>: A candidate plan (one possible supply chain).</br>
# <b>Produced by</b>: coordinator and route.enumerate</br>
# <b>Consumed by</b>: plan.score, plan.validate, coordinator (selection)</br>
#
# **Contains**:<ul>
# <li>selected supplier(s)</li>
# <li>build/assembly location</li>
# <li>shipping lane(s)</li>
# <li>intermediate steps (optional)</li>
# <li>derived properties (optional): total units, lead time, etc.</li>
# </ul></br>
# Key idea: This is the “state” the coordinator searches over.
# </br></br>
#
# <b><i>supply_price_breakdown_v1.json</i></b></br></br>
# <b>Purpose</b>: A line-item cost explanation.</br>
# <b>Produced by</b>: plan.score</br>
# <b>Consumed by</b>: coordinator + user output</br>
#
# **Typical fields**:<ul>
# <li>material_cost</li>
# <li>manufacturing_cost</li>
# <li>shipping_cost</li>
# <li>tariff_cost</li>
# <li>handling_cost</li>
# <li>total_landed_cost</li></ul></br>
# plus “notes” for interpretability</br>
# Why it matters: it turns “trust me” into “show your work.”</br></br>
#
# <b><i>supply_price_v1.json</i></b></br></br>
# <b>Purpose</b>: Score object used for ranking plans.</br>
# <b>Produced by</b>: plan.score</br>
# <b>Consumed by</b>: coordinator (strategy selection + pruning)</br>
#
# **Usually contains**:<ul>
# <li>total_score (lower is better)</li>
# <li>is_valid or validity_status</li>
# <li>breakdown: supply_price_breakdown_v1</li>
# <li>penalties: list (soft constraint violations)</li></ul>
# </br>
# Tip: Keep breakdown separate because humans want it. Strategies want the scalar score.

# %% [markdown]
# ### Message Types and Who Uses Them
#
# **Coordinator receives**:
# <ul><li>supply.solve:v1 → payload: supply_problem_v1</li></ul></br>
#
# **Coordinator calls specialists**:
# <ul><li>route.enumerate:v1 → returns more supply_plan_v1</li>
# <li>plan.validate:v1 → returns validation result (bool + violations)</li>
# <li>plan.score:v1 → returns supply_price_v1</li></ul></br>
#
# **Coordinator returns**:
# <ul><li>supply.solve.result:v1 → best plan + score + trace</li></ul></br>
# </br>
# The coordinator is basically a search engine over supply_plan_v1 states.

# %% [markdown]
# ### What Makes This “Provably Not Fake”
#
# We aren’t claiming the “perfect plan.”
#
# We’re showing:
# <ul><li>every plan is validated</li>
# <li>every score is decomposed (breakdown)</li>
# <li>every step is logged + timed</li>
# <li>the coordinator can run under different budgets</li>
# <li>and a human can look at the output and say:</br>
# “yep, that process makes sense.”</li></ul>
#
# That’s the recruiter-friendly “aha.”

# %% [markdown]
# ### One Tiny Example Payload
# Mini Example (One candidate plan + score)
#
# Candidate plan (supply_plan_v1):
# ```json
# {
#   "type": "supply.plan:v1",
#   "plan_id": "cand-04",
#   "supplier": "VN_raw_01",
#   "assembly_country": "MX",
#   "ship_to": "US",
#   "route": ["VN->MX", "MX->US"]
# }
# ```
# Score (supply_price_v1)
# ```json
# {
#   "type": "supply.price:v1",
#   "total_score": 128.40,
#   "breakdown": {
#     "type": "supply.price_breakdown:v1",
#     "material_cost": 50.0,
#     "manufacturing_cost": 25.0,
#     "shipping_cost": 30.0,
#     "tariff_cost": 20.0,
#     "handling_cost": 3.4,
#     "total_landed_cost": 128.4
#   },
#   "penalties": []
# }
# ```

# %% [markdown]
# ### Mini “Call Graph” Summary
# User → Coordinator
# <ul><li>a2a.request:v1 with message_type="supply.solve:v1" and payload supply_problem_v1</li></ul>
#
# Coordinator → Specialists
# <ul>
# <li>route.enumerate:v1 → returns candidate supply_plan_v1</li>
# <li>plan.validate:v1 → returns pass/fail + violations</li>
# <li>plan.score:v1 → returns supply_price_v1 (+ supply_price_breakdown_v1)</li></ul>
#
# Coordinator → User
# <ul><li>supply.solve.result:v1 with best plan + explanation + trace</li></ul>

# %% [markdown]
# Make every payload schema have:
# <ul><li>type with a const (you’re already doing this)</li>
# <li>$id set to the filename (you learned why the hard way 😄)</li></ul>
#
# That gives you:
# <ul><li>predictable filenames</li>
# <li>resolvable $refs</li>
# <li>predictable validation error paths</li>
# </ul>

# %% [markdown]
# ### Master Contract Mapping
#
# | Schema file                                        | message_type                                          | Producer                 | Consumer                       | Why it exists                                                                                                 |
# | -------------------------------------------------- | ----------------------------------------------------- | ------------------------ | ------------------------------ | ------------------------------------------------------------------------------------------------------------- |
# | **a2a_request_v1.json**                            | `a2a.request:v1`                                      | Any caller               | Any callee                     | Standard “envelope” for *all* A2A requests. Gives routing + traceability.                                     |
# | **a2a_response_v1.json**                           | `a2a.response:v1`                                     | Any callee               | Any caller                     | Standard “envelope” for responses. Clean ok/error semantics + consistent payload validation.                  |
# | **a2a_endpoint_v1.json** *(optional)*              | (embedded object)                                     | N/A                      | N/A                            | Normalizes `source` / `dest` identity objects (name/version/url/skill). Helps debugging and “who called who.” |
# | **supply_problem_v1.json**                         | `supply.solve:v1` *(or `supply.problem:v1` if split)* | User / notebook          | Coordinator                    | Defines the scenario + constraints. Prevents hand-wavy assumptions and makes runs reproducible.               |
# | **supply_plan_v1.json**                            | `supply.plan:v1`                                      | Coordinator / Enumerator | Scorer, Validator, Coordinator | “State” object in search. Everything revolves around proposing/scoring/validating these.                      |
# | **supply_price_breakdown_v1.json**                 | `supply.price_breakdown:v1`                           | Scorer                   | Coordinator / Report           | Line-item cost explanation. Makes scoring legible and audit-friendly.                                         |
# | **supply_price_v1.json**                           | `supply.price:v1`                                     | Scorer                   | Coordinator                    | Ranking signal used by strategies. Scalar score for pruning + breakdown for humans.                           |
# | **supply_trace_event_v1.json**                     | `supply.trace_event:v1`                               | Coordinator              | Final report                   | Standard “step log” contract: what was tried, what it cost, what got selected, and why.                       |
# | **supply_strategy_config_v1.json**                 | `supply.strategy_config:v1`                           | User / Policy            | Coordinator                    | Makes strategy choice explicit: fixed/policy/adaptive + requested vs selected strategy + budget knobs.        |
# | **route_enumerate_v1.json** *(if you add it)*      | `route.enumerate:v1`                                  | Coordinator              | Enumerator agent               | Generates candidate plans. Keeps “search branching” decoupled from scoring logic.                             |
# | **plan_validate_v1.json** *(if you add it)*        | `plan.validate:v1`                                    | Coordinator              | Validator agent                | Validity check is explicit, testable, and separate from scoring heuristics.                                   |
# | **plan_score_v1.json** *(if you add it)*           | `plan.score:v1`                                       | Coordinator              | Scorer agent                   | Scoring request stays clean: input plan + problem context → output score + breakdown.                         |
# | **supply_solve_result_v1.json**                    | `supply.solve.result:v1`                              | Coordinator              | User / notebook                | Final deliverable: best plan + score + trace summary. This is the “artifact” you screenshot for LinkedIn.     |

# %% [markdown]
# ## Driver

# %%
from pathlib import Path
import os, sys
from IPython.display import JSON
from a2a.core import start_uvicorn, wait_http_ok, tail, stop_proc
import json


# Find repo root
def find_repo_root(start: Path) -> Path:
    for p in [start] + list(start.parents):
        if (p / "pyproject.toml").exists():
            return p
    raise RuntimeError("pyproject.toml not found")

REPO_ROOT = find_repo_root(Path.cwd())
SRC_DIR = REPO_ROOT / "src"
APP_DIR = SRC_DIR / "demos" / "a2a_supplychain" 
PROBLEMS_DIR = APP_DIR / "problems"

sys.path.insert(0, str(SRC_DIR))


HOST = "127.0.0.1"
ROOT_DIR = REPO_ROOT

agents = {
    "solve":    ("solve_agent:app",    8200),
    "propose":  ("propose_agent:app",  8201),
    "price":    ("price_agent:app",    8202),
    "validate": ("validate_agent:app", 8203),
}

child_env = {}
if os.getenv("OPENAI_API_KEY"):
    child_env["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

procs = {}
for name, (spec, port) in agents.items():
    url = f"http://{HOST}:{port}/.well-known/agent.json"
    try:
        wait_http_ok(url, timeout_s=0.5)
        print(f"✅ {name} already running on {port}")
        continue
    except Exception:
        pass

    print(f"▶ starting {name} on {port} ...")
    p = start_uvicorn(spec, HOST, port, cwd=ROOT_DIR, env=child_env, app_dir=APP_DIR)
    procs[name] = p

    try:
        wait_http_ok(url, timeout_s=15)
        print(f"✅ {name} up: {url}")
    except Exception as e:
        print(f"❌ {name} failed: {e}")
        print(tail(p, n=120))
        stop_proc(p)
        raise

print("Running:", list(procs.keys()))
# Out:
# ▶ starting solve on 8200 ...
# ✅ solve up: http://127.0.0.1:8200/.well-known/agent.json
# ▶ starting propose on 8201 ...
# ✅ propose up: http://127.0.0.1:8201/.well-known/agent.json
# ▶ starting price on 8202 ...
# ✅ price up: http://127.0.0.1:8202/.well-known/agent.json
# ▶ starting validate on 8203 ...
# ✅ validate up: http://127.0.0.1:8203/.well-known/agent.json
# Running: ['solve', 'propose', 'price', 'validate']

# %% [markdown]
# ### Propose
# Generate candidate plans (based on mutation, n_candidates, maybe base_plan)

# %%
from a2a.client import a2a_send
from a2a.envelope import make_endpoint, make_request

SRC  = make_endpoint(name="NOTEBOOK", url="local://notebook", skill="client")
DEST = make_endpoint(name="PROPOSE", url="http://127.0.0.1:8201", skill="supply.propose")

problem_path = PROBLEMS_DIR / "toy_03.problem.json"
problem = json.loads(problem_path.read_text())

req = make_request(
    message_type="supply.propose:v1",
    payload={
        "type": "supply.propose:v1",
        "problem": problem,     
        "n_candidates": 5,
        "mutation": "greedy",
        "seed": 0
    },
    source=SRC,
    dest=DEST,
)

task = a2a_send("http://127.0.0.1:8201", req_id=req["request_id"], msg_obj=req)
meta = task["meta"]
print(json.dumps(meta["payload"], indent=2, sort_keys=True))
# Out:
# {
#   "candidates": [
#     {
#       "assembly_country": "MX",
#       "component_sources": [
#         {
#           "component_id": "SENSOR",
#           "country": "MX"
#         },
#         {
#           "component_id": "CPU",
#           "country": "US"
#         }
#       ],
#       "ship_mode": "AIR",
#       "type": "supply.plan:v1"
#     },
#     {
#       "assembly_country": "US",
#       "component_sources": [
#         {
#           "component_id": "SENSOR",
#           "country": "CN"
#         },
#         {
#           "component_id": "CPU",
#           "country": "US"
#         }
#       ],
#       "ship_mode": "AIR",
#       "type": "supply.plan:v1"
#     }
#   ],
#   "type": "supply.propose.result:v1"
# }

# %% [markdown]
# ### Validate
# Check constraints for a single plan

# %%
from a2a.envelope import make_endpoint, make_request
from a2a.client import a2a_send
import json

SRC = make_endpoint(name="NOTEBOOK", url="local", skill="demo")
DEST = make_endpoint(name="VALIDATE", url="http://127.0.0.1:8203", skill="supply.validate")

problem = json.loads(open(problem_path).read())
plan = meta["payload"]["candidates"][0]

req = make_request(
    message_type="supply.validate:v1",
    payload={"type":"supply.validate:v1", "problem": problem, "plan": plan},
    source=SRC,
    dest=DEST,
)

task = a2a_send("http://127.0.0.1:8203", req_id=req["request_id"], msg_obj=req)
validation = task["meta"]["payload"]
print(json.dumps(validation, indent=2))
# Out:
# {
#   "type": "supply.validation:v1",
#   "ok": true,
#   "reasons": []
# }

# %% [markdown]
# ### Price
# Score a single plan

# %%
DEST = make_endpoint(name="PRICE", url="http://127.0.0.1:8202", skill="supply.price")

req = make_request(
    message_type="supply.price:v1",
    payload={
        "type": "supply.price:v1",
        "problem": problem,   # the full supply.problem:v1 dict (not $ref)
        "plan": plan,         # the supply.plan:v1 dict
    },
    source=SRC,
    dest=DEST,
)

task = a2a_send("http://127.0.0.1:8202", req_id=req["request_id"], msg_obj=req)
print(json.dumps(task["meta"]["payload"], indent=2))
# Out:
# {
#   "type": "supply.price_breakdown:v1",
#   "ok": true,
#   "total_cost": 35.7,
#   "total_lead_days": 10,
#   "line_items": [
#     {
#       "kind": "component_cost",
#       "amount": 21.0
#     },
#     {
#       "kind": "component_tariff",
#       "amount": 0.0
#     },
#     {
#       "kind": "assembly_labor",
#       "amount": 4.0
#     },
#     {
#       "kind": "shipping",
#       "amount": 9.0
#     },
#     {
#       "kind": "finished_good_tariff",
#       "amount": 1.7
#     }
#   ]
# }

# %% [markdown]
# ### Solve
# The orchestrator. It gets a problem + budget + strategy_config, then loops:
#
# propose → validate → price → keep best → log trace → stop when budget hit

# %%
DEST = make_endpoint(name="SOLVE", url="http://127.0.0.1:8200", skill="supply.solve")

import json

payload = {
    "type": "supply.solve:v1",
    "problem": problem,                 # your dict
    "evaluation_budget": 50,           # or toy_03["budget"]["max_evaluations"]
    "strategy_config": {
        "type": "supply.strategy.config:v1",
        "selection_method": "fixed",
        "strategy_requested": "anneal",
        "strategy_selected": "anneal",
        "params": {
            "random_seed": 0,
            "anneal": {
                "t_start": 5.0,
                "t_end": 0.2,
                "cooling": 0.97
            }
        },
        "notes": "anneal on toy_03"
    }
}

req = make_request(
    message_type="supply.solve:v1",
    payload=payload,
    source=SRC,
    dest=DEST,
)

task = a2a_send("http://127.0.0.1:8200", req_id=req["request_id"], msg_obj=req)
meta = task["meta"]
print(json.dumps(meta["payload"], indent=2))
# Out:
# {
#   "type": "supply.solve.result:v1",
#   "ok": true,
#   "best_plan": {
#     "type": "supply.plan:v1",
#     "component_sources": [
#       {
#         "component_id": "SENSOR",
#         "country": "CN"
#       },
#       {
#         "component_id": "CPU",
#         "country": "US"
#       }
#     ],
#     "assembly_country": "MX",
#     "ship_mode": "AIR"
#   },
#   "best_price": {
#     "type": "supply.price_breakdown:v1",
#     "ok": true,
#     "total_cost": 34.02,
#     "total_lead_days": 15,
#     "line_items": [
#       {
#         "kind": "component_cost",
#         "amount": 19.0
#       },
#       {
#         "kind": "component_tariff",
#         "amount": 0.4
#       },
#       {
#         "kind": "assembly_labor",
#         "amount": 4.0
#       },
#       {
#         "kind": "shipping",
#         "amount": 9.0
#       },
#       {
#         "kind": "finished_good_tariff",
#         "amount": 1.62
#       }
#     ]
#   },
#   "evaluations_used": 50,
#   "evaluation_budget": 50,
#   "strategy_config": {
#     "type": "supply.strategy.config:v1",
#     "selection_method": "fixed",
#     "strategy_requested": "anneal",
#     "strategy_selected": "anneal",
#     "params": {
#       "random_seed": 0,
#       "anneal": {
#         "t_start": 5.0,
#         "t_end": 0.2,
#         "cooling": 0.97
#       }
#     },
#     "notes": "anneal on toy_03"
#   },
#   "trace": [
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 1,
#       "action": "seed_greedy",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 35.7,
#       "latency_ms": 35.631,
#       "note": "anneal seed"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 2,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 38.0,
#         "total_lead_days": 9,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 35.7,
#       "latency_ms": 16.843,
#       "note": "anneal T=5.000 cur=35.70 cand=38.00 delta=+2.30 best=35.70 accept=False (worse p=0.631 r=0.758)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 3,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 38.0,
#         "total_lead_days": 9,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 35.7,
#       "latency_ms": 16.468,
#       "note": "anneal T=4.850 cur=35.70 cand=38.00 delta=+2.30 best=35.70 accept=True (worse p=0.622 r=0.040)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 4,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 38.0,
#         "total_lead_days": 9,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 35.7,
#       "latency_ms": 16.365,
#       "note": "anneal T=4.704 cur=38.00 cand=38.00 delta=+0.00 best=35.70 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 5,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 35.7,
#       "latency_ms": 16.45,
#       "note": "anneal T=4.563 cur=38.00 cand=35.70 delta=-2.30 best=35.70 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 6,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 38.0,
#         "total_lead_days": 9,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 35.7,
#       "latency_ms": 15.853,
#       "note": "anneal T=4.426 cur=35.70 cand=38.00 delta=+2.30 best=35.70 accept=False (worse p=0.595 r=0.918)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 7,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 38.0,
#         "total_lead_days": 9,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 35.7,
#       "latency_ms": 15.993,
#       "note": "anneal T=4.294 cur=35.70 cand=38.00 delta=+2.30 best=35.70 accept=False (worse p=0.585 r=0.968)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 8,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 38.0,
#         "total_lead_days": 9,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 35.7,
#       "latency_ms": 21.041,
#       "note": "anneal T=4.165 cur=35.70 cand=38.00 delta=+2.30 best=35.70 accept=False (worse p=0.576 r=0.583)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 9,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 16.169,
#       "note": "anneal T=4.040 cur=35.70 cand=34.02 delta=-1.68 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 10,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.803,
#       "note": "anneal T=3.919 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 11,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.767,
#       "note": "anneal T=3.801 cur=34.02 cand=35.70 delta=+1.68 best=34.02 accept=True (worse p=0.643 r=0.282)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 12,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.31,
#       "note": "anneal T=3.687 cur=35.70 cand=34.02 delta=-1.68 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 13,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.717,
#       "note": "anneal T=3.577 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 14,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 36.8,
#         "total_lead_days": 14,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.8
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.608,
#       "note": "anneal T=3.469 cur=34.02 cand=36.80 delta=+2.78 best=34.02 accept=False (worse p=0.449 r=0.987)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 15,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.271,
#       "note": "anneal T=3.365 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 16,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.189,
#       "note": "anneal T=3.264 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 17,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.087,
#       "note": "anneal T=3.166 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 18,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.241,
#       "note": "anneal T=3.071 cur=34.02 cand=35.70 delta=+1.68 best=34.02 accept=True (worse p=0.579 r=0.310)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 19,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.182,
#       "note": "anneal T=2.979 cur=35.70 cand=35.70 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 20,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.176,
#       "note": "anneal T=2.890 cur=35.70 cand=34.02 delta=-1.68 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 21,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.912,
#       "note": "anneal T=2.803 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 22,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 36.8,
#         "total_lead_days": 14,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.8
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.737,
#       "note": "anneal T=2.719 cur=34.02 cand=36.80 delta=+2.78 best=34.02 accept=False (worse p=0.360 r=0.472)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 23,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.546,
#       "note": "anneal T=2.637 cur=34.02 cand=35.70 delta=+1.68 best=34.02 accept=True (worse p=0.529 r=0.354)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 24,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 38.0,
#         "total_lead_days": 9,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.276,
#       "note": "anneal T=2.558 cur=35.70 cand=38.00 delta=+2.30 best=34.02 accept=False (worse p=0.407 r=0.611)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 25,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.705,
#       "note": "anneal T=2.482 cur=35.70 cand=34.02 delta=-1.68 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 26,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.915,
#       "note": "anneal T=2.407 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 27,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 36.8,
#         "total_lead_days": 14,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.8
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.988,
#       "note": "anneal T=2.335 cur=34.02 cand=36.80 delta=+2.78 best=34.02 accept=False (worse p=0.304 r=0.443)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 28,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.825,
#       "note": "anneal T=2.265 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 29,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 36.8,
#         "total_lead_days": 14,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.8
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.703,
#       "note": "anneal T=2.197 cur=34.02 cand=36.80 delta=+2.78 best=34.02 accept=True (worse p=0.282 r=0.062)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 30,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 36.8,
#         "total_lead_days": 14,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.8
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.02,
#       "note": "anneal T=2.131 cur=36.80 cand=36.80 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 31,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 38.0,
#         "total_lead_days": 9,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.866,
#       "note": "anneal T=2.067 cur=36.80 cand=38.00 delta=+1.20 best=34.02 accept=True (worse p=0.560 r=0.093)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 32,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.977,
#       "note": "anneal T=2.005 cur=38.00 cand=35.70 delta=-2.30 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 33,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.779,
#       "note": "anneal T=1.945 cur=35.70 cand=35.70 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 34,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.47,
#       "note": "anneal T=1.887 cur=35.70 cand=35.70 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 35,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
# ...
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 36.8,
#         "total_lead_days": 14,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.8
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.192,
#       "note": "anneal T=1.620 cur=34.02 cand=36.80 delta=+2.78 best=34.02 accept=False (worse p=0.180 r=0.244)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 40,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 36.8,
#         "total_lead_days": 14,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.8
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.541,
#       "note": "anneal T=1.571 cur=34.02 cand=36.80 delta=+2.78 best=34.02 accept=False (worse p=0.170 r=0.704)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 41,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.859,
#       "note": "anneal T=1.524 cur=34.02 cand=35.70 delta=+1.68 best=34.02 accept=True (worse p=0.332 r=0.191)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 42,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.869,
#       "note": "anneal T=1.479 cur=35.70 cand=35.70 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 43,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.116,
#       "note": "anneal T=1.434 cur=35.70 cand=34.02 delta=-1.68 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 44,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 16.635,
#       "note": "anneal T=1.391 cur=34.02 cand=35.70 delta=+1.68 best=34.02 accept=False (worse p=0.299 r=0.803)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 45,
#       "action": "mutate_supplier",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "MX"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 35.7,
#         "total_lead_days": 10,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 21.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.0
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.7
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 17.554,
#       "note": "anneal T=1.349 cur=34.02 cand=35.70 delta=+1.68 best=34.02 accept=False (worse p=0.288 r=0.803)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 46,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 36.8,
#         "total_lead_days": 14,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.8
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 17.084,
#       "note": "anneal T=1.309 cur=34.02 cand=36.80 delta=+2.78 best=34.02 accept=True (worse p=0.120 r=0.091)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 47,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 16.22,
#       "note": "anneal T=1.270 cur=36.80 cand=34.02 delta=-2.78 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 48,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.504,
#       "note": "anneal T=1.232 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 49,
#       "action": "mutate_assembly",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "US",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 36.8,
#         "total_lead_days": 14,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.8
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 8.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 0.0
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 14.915,
#       "note": "anneal T=1.195 cur=34.02 cand=36.80 delta=+2.78 best=34.02 accept=False (worse p=0.098 r=0.109)"
#     },
#     {
#       "type": "supply.trace.event:v1",
#       "eval_i": 50,
#       "action": "mutate_shipping",
#       "candidate": {
#         "type": "supply.plan:v1",
#         "component_sources": [
#           {
#             "component_id": "SENSOR",
#             "country": "CN"
#           },
#           {
#             "component_id": "CPU",
#             "country": "US"
#           }
#         ],
#         "assembly_country": "MX",
#         "ship_mode": "AIR"
#       },
#       "validation": {
#         "type": "supply.validation:v1",
#         "ok": true,
#         "reasons": []
#       },
#       "price": {
#         "type": "supply.price_breakdown:v1",
#         "ok": true,
#         "total_cost": 34.02,
#         "total_lead_days": 15,
#         "line_items": [
#           {
#             "kind": "component_cost",
#             "amount": 19.0
#           },
#           {
#             "kind": "component_tariff",
#             "amount": 0.4
#           },
#           {
#             "kind": "assembly_labor",
#             "amount": 4.0
#           },
#           {
#             "kind": "shipping",
#             "amount": 9.0
#           },
#           {
#             "kind": "finished_good_tariff",
#             "amount": 1.62
#           }
#         ]
#       },
#       "best_so_far_cost": 34.02,
#       "latency_ms": 15.218,
#       "note": "anneal T=1.159 cur=34.02 cand=34.02 delta=+0.00 best=34.02 accept=True (better_or_equal)"
#     }
#   ]
# }

# %% [markdown]
# Two quick upgrades that’ll make the next steps cleaner:
#
# Include plan in the price response (optional but useful)
# So downstream trace/debugging doesn’t need to stitch it back together.
#
# Make line_items richer (later)
# Right now “component_cost = 18” hides which component(s). Eventually you’ll want:
#
# per-component costs (WIDGET, GIZMO)
#
# per-tariff leg (CN→MX import, MX→US finished good)
# This makes the “aha” obvious to humans.
